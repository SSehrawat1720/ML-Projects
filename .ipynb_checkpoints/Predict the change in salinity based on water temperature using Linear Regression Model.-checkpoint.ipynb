# %% [markdown]
# # Data set Context
#
# The CalCOFI data set represents the longest (1949-present) and most complete (more than 50,000 sampling stations) time series of oceanographic and larval fish data in the world. It includes abundance data on the larvae of over 250 species of fish; larval length frequency data and egg abundance data on key commercial species; and oceanographic and plankton data. The physical, chemical, and biological data collected at regular time and space intervals quickly became valuable for documenting climatic cycles in the California Current and a range of biological responses to them. CalCOFI research drew world attention to the biological response to the dramatic Pacific-warming event in 1957-58 and introduced the term “El Niño” into the scientific literature.
#
# The California Cooperative Oceanic Fisheries Investigations (CalCOFI) are a unique partnership of the California Department of Fish & Wildlife, NOAA Fisheries Service and Scripps Institution of Oceanography. The organization was formed in 1949 to study the ecological aspects of the sardine population collapse off California. Today our focus has shifted to the study of the marine environment off the coast of California, the management of its living resources, and monitoring the indicators of El Nino and climate change. CalCOFI conducts quarterly cruises off southern & central California, collecting a suite of hydrographic and biological data on station and underway. Data collected at depths down to 500 m include: temperature, salinity, oxygen, phosphate, silicate, nitrate and nitrite, chlorophyll, transmissometer, PAR, C14 primary productivity, phytoplankton biodiversity, zooplankton biomass, and zooplankton biodiversity.

# %% [markdown]
# # Task  :
# In this project we investigate the relationship between water salinity and water temperature. Also we predict the change of salinity based on water temperature.

# %% [markdown]
# # Imorting All Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error,max_error

# %% [markdown]
# **Importing Data Set** :
# Importing dataset from downloaded file on System using Pandas package

# %%
original_data = pd .read_csv( "C:\\Users\\SS\\Downloads\\MDS Course files\\Projects\\Data Sets\\calcofi ULR & MLR\\bottle.csv" )
# Out:
# C:\Users\SS\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
original_data .head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  ...  R_PHAEO  R_PRES  \
# 0       0   10.50  33.440     NaN  25.649    NaN  ...      NaN       0
# 1       8   10.46  33.440     NaN  25.656    NaN  ...      NaN       8
# 2      10   10.46  33.437     NaN  25.654    NaN  ...      NaN      10
# 3      19   10.45  33.420     NaN  25.643    NaN  ...      NaN      19
# 4      20   10.45  33.421     NaN  25.643    NaN  ...      NaN      20
#
#    R_SAMP  DIC1  DIC2  TA1  TA2  pH2  pH1  DIC Quality Comment
# 0     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 1     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 2     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 3     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 4     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
#
# [5 rows x 74 columns]

# %% [markdown]
# This Shows Data has 74 columns. But we dont know the no. of entries. So, We find **SHAPE** of the data

# %%
original_data .shape
# Out:
# (864863, 74)

# %% [markdown]
# This dataset has 864863 enteries/rows and 74 features/columns

# %% [markdown]
# ### Info on features/columns of the Data set

# %%
original_data .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 74 columns):
# Cst_Cnt                864863 non-null int64
# Btl_Cnt                864863 non-null int64
# Sta_ID                 864863 non-null object
# Depth_ID               864863 non-null object
# Depthm                 864863 non-null int64
# T_degC                 853900 non-null float64
# Salnty                 817509 non-null float64
# O2ml_L                 696201 non-null float64
# STheta                 812174 non-null float64
# O2Sat                  661274 non-null float64
# Oxy_µmol/Kg            661268 non-null float64
# BtlNum                 118667 non-null float64
# RecInd                 864863 non-null int64
# T_prec                 853900 non-null float64
# T_qual                 23127 non-null float64
# S_prec                 817509 non-null float64
# S_qual                 74914 non-null float64
# P_qual                 673755 non-null float64
# O_qual                 184676 non-null float64
# SThtaq                 65823 non-null float64
# O2Satq                 217797 non-null float64
# ChlorA                 225272 non-null float64
# Chlqua                 639166 non-null float64
# Phaeop                 225271 non-null float64
# Phaqua                 639170 non-null float64
# PO4uM                  413317 non-null float64
# PO4q                   451786 non-null float64
# SiO3uM                 354091 non-null float64
# SiO3qu                 510866 non-null float64
# NO2uM                  337576 non-null float64
# NO2q                   529474 non-null float64
# NO3uM                  337403 non-null float64
# NO3q                   529933 non-null float64
# NH3uM                  64962 non-null float64
# NH3q                   808299 non-null float64
# C14As1                 14432 non-null float64
# C14A1p                 12760 non-null float64
# C14A1q                 848605 non-null float64
# C14As2                 14414 non-null float64
# C14A2p                 12742 non-null float64
# C14A2q                 848623 non-null float64
# DarkAs                 22649 non-null float64
# DarkAp                 20457 non-null float64
# DarkAq                 840440 non-null float64
# MeanAs                 22650 non-null float64
# MeanAp                 20457 non-null float64
# MeanAq                 840439 non-null float64
# IncTim                 14437 non-null object
# LightP                 18651 non-null float64
# R_Depth                864863 non-null float64
# R_TEMP                 853900 non-null float64
# R_POTEMP               818816 non-null float64
# R_SALINITY             817509 non-null float64
# R_SIGMA                812007 non-null float64
# R_SVA                  812092 non-null float64
# R_DYNHT                818206 non-null float64
# R_O2                   696201 non-null float64
# R_O2Sat                666448 non-null float64
# R_SIO3                 354099 non-null float64
# R_PO4                  413325 non-null float64
# R_NO3                  337411 non-null float64
# R_NO2                  337584 non-null float64
# R_NH4                  64982 non-null float64
# R_CHLA                 225276 non-null float64
# R_PHAEO                225275 non-null float64
# R_PRES                 864863 non-null int64
# R_SAMP                 122006 non-null float64
# DIC1                   1999 non-null float64
# DIC2                   224 non-null float64
# TA1                    2084 non-null float64
# TA2                    234 non-null float64
# pH2                    10 non-null float64
# pH1                    84 non-null float64
# DIC Quality Comment    55 non-null object
# dtypes: float64(65), int64(5), object(4)
# memory usage: 488.3+ MB

# %% [markdown]
# Result of this code shows 65 features are of float data type , 5 are of int data type and 4 are objects.

# %% [markdown]
# ### Statistical Information of the Data set

# %%
original_data .describe()
# Out:
#              Cst_Cnt        Btl_Cnt         Depthm         T_degC  \
# count  864863.000000  864863.000000  864863.000000  853900.000000
# mean    17138.790958  432432.000000     226.831951      10.799677
# std     10240.949817  249664.587267     316.050259       4.243825
# min         1.000000       1.000000       0.000000       1.440000
# 25%      8269.000000  216216.500000      46.000000       7.680000
# 50%     16848.000000  432432.000000     125.000000      10.060000
# 75%     26557.000000  648647.500000     300.000000      13.880000
# max     34404.000000  864863.000000    5351.000000      31.140000
#
#               Salnty         O2ml_L         STheta          O2Sat  \
# count  817509.000000  696201.000000  812174.000000  661274.000000
# mean       33.840350       3.392468      25.819394      57.103779
# std         0.461843       2.073256       1.167787      37.094137
# min        28.431000      -0.010000      20.934000      -0.100000
# 25%        33.488000       1.360000      24.965000      21.100000
# 50%        33.863000       3.440000      25.996000      54.400000
# 75%        34.196900       5.500000      26.646000      97.600000
# max        37.034000      11.130000     250.784000     214.100000
#
#          Oxy_µmol/Kg         BtlNum  ...         R_CHLA        R_PHAEO  \
# count  661268.000000  118667.000000  ...  225276.000000  225275.000000
# mean      148.808694      10.497426  ...       0.450225       0.198599
# std        90.187533       6.189688  ...       1.208566       0.376539
# min        -0.434900       0.000000  ...      -0.010000      -3.890000
# 25%        60.915470       5.000000  ...       0.050000       0.050000
# 50%       151.064150      10.000000  ...       0.160000       0.110000
# 75%       240.379600      16.000000  ...       0.390000       0.230000
# max       485.701800      25.000000  ...      66.110000      65.300000
#
#               R_PRES         R_SAMP         DIC1         DIC2          TA1  \
# count  864863.000000  122006.000000  1999.000000   224.000000  2084.000000
# mean      228.395694     162.071521  2153.239714  2168.148330  2256.055845
# std       319.456731      85.722796   112.995202   154.852332    34.844435
# min         0.000000       0.000000  1948.850000  1969.440000  2181.570000
# 25%        46.000000     200.000000  2028.330000  2008.977500  2230.322500
# 50%       126.000000     206.000000  2170.640000  2265.885000  2244.325000
# 75%       302.000000     214.000000  2253.810000  2315.525000  2278.505000
# max      5458.000000     424.000000  2367.800000  2364.420000  2434.900000
#
#                TA2        pH2        pH1
# count   234.000000  10.000000  84.000000
# mean   2278.858803   7.948570   7.910983
# std      58.496495   0.021216   0.077666
# min    2198.150000   7.923100   7.618300
# 25%    2229.062500   7.931475   7.898675
# 50%    2247.505000   7.946650   7.928850
# 75%    2316.452500   7.963300   7.955100
# max    2437.000000   7.988300   8.047700
#
# [8 rows x 70 columns]

# %% [markdown]
# ### Correlation between Features with numerical value of the Data set with each other

# %% [markdown]
# ### First we remove features of dtype object from original_data
# because correlation only applied on continues values

# %%
original_data = original_data.select_dtypes(exclude=['object'])

# %%
original_data .corr()
# Out:
#               Cst_Cnt   Btl_Cnt    Depthm    T_degC    Salnty    O2ml_L  \
# Cst_Cnt      1.000000  0.999345 -0.162222  0.089329 -0.198024  0.156096
# Btl_Cnt      0.999345  1.000000 -0.161617  0.090118 -0.195207  0.154219
# Depthm      -0.162222 -0.161617  1.000000 -0.681201  0.572630 -0.592399
# T_degC       0.089329  0.090118 -0.681201  1.000000 -0.505266  0.795700
# Salnty      -0.198024 -0.195207  0.572630 -0.505266  1.000000 -0.823870
# O2ml_L       0.156096  0.154219 -0.592399  0.795700 -0.823870  1.000000
# STheta      -0.089902 -0.089521  0.582710 -0.829155  0.603470 -0.889568
# O2Sat        0.136510  0.134732 -0.595547  0.850596 -0.790231  0.993217
# Oxy_µmol/Kg  0.147493  0.145498 -0.589175  0.795543 -0.824338  0.999999
# BtlNum      -0.026749 -0.027514 -0.681935  0.750413 -0.693341  0.744968
# RecInd      -0.100142 -0.100828  0.082316 -0.066507  0.067320 -0.073912
# T_prec       0.067977  0.062864  0.019422 -0.041076 -0.019075  0.001241
# T_qual      -0.840300 -0.847992 -0.257070  0.162308 -0.191714  0.380105
# S_prec       0.458220  0.456784  0.005934 -0.036218 -0.079280  0.026635
# S_qual      -0.899177 -0.900722  0.143708 -0.059252  0.207788 -0.079644
# P_qual      -0.002683 -0.002741  0.000775 -0.000631  0.002334 -0.001828
# O_qual      -0.563832 -0.574244  0.006826  0.040984  0.039711  0.030653
# SThtaq      -0.780221 -0.784094  0.071524 -0.033225 -0.166754 -0.036027
# O2Satq      -0.457026 -0.465335  0.017948  0.012337  0.041840 -0.034561
# ChlorA       0.005756  0.009596 -0.279623  0.108915 -0.029364  0.269654
# Chlqua      -0.021278 -0.020895  0.006753 -0.006510  0.010279 -0.012002
# Phaeop      -0.040761 -0.035966 -0.201464  0.014997 -0.003073  0.151938
# Phaqua      -0.021694 -0.021321  0.006941 -0.006761  0.010728 -0.012663
# PO4uM       -0.159404 -0.157624  0.667351 -0.904177  0.825373 -0.973389
# PO4q        -0.036510 -0.036072 -0.000514 -0.000423 -0.005705  0.000550
# SiO3uM      -0.054884 -0.052719  0.846583 -0.840342  0.795998 -0.894005
# SiO3qu      -0.031979 -0.031528 -0.004010 -0.000285 -0.002501 -0.001290
# NO2uM        0.002367  0.005897 -0.158329  0.097438 -0.151627  0.188103
# NO2q        -0.180492 -0.181636  0.011480 -0.016217  0.023391 -0.008287
# NO3uM       -0.001969  0.000945  0.687875 -0.925475  0.849224 -0.969969
# ...               ...       ...       ...       ...       ...       ...
# DarkAp      -0.021867 -0.023403  0.064378 -0.020106 -0.058609 -0.157342
# DarkAq      -0.002954 -0.002821  0.001863 -0.004066  0.003950 -0.003977
# MeanAs       0.019067  0.021229 -0.262304 -0.012035  0.179633  0.283113
# MeanAp       0.003529  0.000793  0.613581 -0.332483  0.092569 -0.396630
# MeanAq      -0.003116 -0.003000  0.002004 -0.004214  0.004141 -0.004191
# LightP      -0.361108 -0.369160 -0.472293  0.341392 -0.028926  0.155446
# R_Depth     -0.162220 -0.161614  1.000000 -0.681200  0.572629 -0.592399
# R_TEMP       0.089337  0.090126 -0.681202  1.000000 -0.505268  0.795701
# R_POTEMP     0.071169  0.072048 -0.679035  0.999954 -0.507023  0.795181
# R_SALINITY  -0.197496 -0.194687  0.571185 -0.503959  0.997428 -0.821229
# R_SIGMA     -0.095794 -0.095405  0.606262 -0.862161  0.628311 -0.889732
# R_SVA        0.107822  0.107463 -0.669232  0.964171 -0.698367  0.886580
# R_DYNHT     -0.138037 -0.138205  0.927118 -0.799025  0.669824 -0.767520
# R_O2         0.156117  0.154240 -0.592399  0.795700 -0.823871  0.999998
# R_O2Sat      0.133260  0.131503 -0.596687  0.850365 -0.790542  0.993216
# R_SIO3      -0.054867 -0.052701  0.846587 -0.840343  0.796000 -0.894007
# R_PO4       -0.159410 -0.157630  0.667357 -0.904179  0.825378 -0.973389
# R_NO3       -0.001971  0.000943  0.687878 -0.925476  0.849227 -0.969970
# R_NO2        0.002631  0.006174 -0.158345  0.097463 -0.151664  0.188108
# R_NH4        0.022702  0.022562 -0.164482  0.132263 -0.118660  0.169554
# R_CHLA       0.005807  0.009648 -0.279636  0.108925 -0.029373  0.269659
# R_PHAEO     -0.040576 -0.035778 -0.201450  0.014987 -0.003063  0.151917
# R_PRES      -0.161961 -0.161348  0.999994 -0.679852  0.571405 -0.590598
# R_SAMP      -0.604945 -0.595142 -0.018605  0.006503 -0.000758  0.053971
# DIC1        -0.036155 -0.035516  0.567855 -0.936239  0.938153 -0.977188
# DIC2        -0.097938 -0.097251  0.572374 -0.949972  0.955942 -0.941214
# TA1         -0.075060 -0.074255  0.786873 -0.742196  0.895124 -0.802493
# TA2         -0.115212 -0.114165  0.866185 -0.889635  0.937147 -0.726460
# pH2         -0.262587 -0.259082  0.223304  0.547436  0.583807  0.174204
# pH1          0.020778  0.020315 -0.611798  0.743735  0.106417  0.663591
#
#                STheta     O2Sat  Oxy_µmol/Kg    BtlNum  ...    R_CHLA  \
# Cst_Cnt     -0.089902  0.136510     0.147493 -0.026749  ...  0.005807
# Btl_Cnt     -0.089521  0.134732     0.145498 -0.027514  ...  0.009648
# Depthm       0.582710 -0.595547    -0.589175 -0.681935  ... -0.279636
# T_degC      -0.829155  0.850596     0.795543  0.750413  ...  0.108925
# Salnty       0.603470 -0.790231    -0.824338 -0.693341  ... -0.029373
# O2ml_L      -0.889568  0.993217     0.999999  0.744968  ...  0.269659
# STheta       1.000000 -0.876899    -0.890043 -0.378342  ... -0.084765
# O2Sat       -0.876899  1.000000     0.993343  0.755972  ...  0.250458
# Oxy_µmol/Kg -0.890043  0.993343     1.000000  0.745210  ...  0.272914
# BtlNum      -0.378342  0.755972     0.745210  1.000000  ... -0.007772
# RecInd       0.060133 -0.066473    -0.068444  0.179955  ... -0.024936
# T_prec       0.026236 -0.009523    -0.005486 -0.000409  ...  0.012540
# T_qual      -0.129381  0.062651     0.045017 -0.739895  ...  0.254486
# S_prec       0.006887  0.021311     0.032187  0.005291  ... -0.000220
# S_qual       0.022933 -0.048010    -0.059043  0.204317  ...  0.309209
# P_qual       0.001232 -0.001733    -0.001881 -0.345106  ...       NaN
# O_qual      -0.012529  0.039763     0.030247  0.414233  ...  0.232595
# SThtaq       0.007877 -0.060385    -0.074465  0.679854  ...  0.290527
# O2Satq      -0.006809 -0.066319    -0.079409  0.353010  ...  0.217429
# ChlorA      -0.084754  0.250452     0.272910 -0.007791  ...  1.000000
# Chlqua       0.006817 -0.012055    -0.012568 -0.058390  ...  0.082509
# Phaeop       0.008723  0.126200     0.154789 -0.055533  ...  0.695120
# Phaqua       0.007104 -0.012732    -0.013257 -0.058347  ...  0.057525
# PO4uM        0.948210 -0.984222    -0.974888 -0.764347  ... -0.179303
# PO4q        -0.001362  0.001440     0.001764  0.031192  ...  0.007485
# SiO3uM       0.864654 -0.890058    -0.894686 -0.744149  ... -0.177711
# SiO3qu      -0.000205 -0.001215    -0.001041  0.012802  ...  0.011065
# NO2uM       -0.107861  0.170192     0.190166  0.065557  ...  0.197828
# NO2q         0.017957 -0.011206    -0.008184  0.071274  ...  0.070941
# NO3uM        0.958111 -0.983084    -0.970844 -0.761359  ... -0.187845
# ...               ...       ...          ...       ...  ...       ...
# DarkAp       0.002274 -0.145349    -0.157753  0.020580  ... -0.368427
# DarkAq       0.004151 -0.004477    -0.004064       NaN  ... -0.001738
# MeanAs       0.067722  0.239013     0.283094 -0.018259  ...  0.767591
# MeanAp       0.332838 -0.443824    -0.398605 -0.310803  ... -0.156651
# MeanAq       0.004316 -0.004716    -0.004284 -0.005431  ... -0.001892
# LightP      -0.337227  0.255380     0.156742  0.078719  ... -0.031167
# R_Depth      0.582711 -0.595547    -0.589175 -0.681917  ... -0.279636
# R_TEMP      -0.829156  0.850597     0.795544  0.750412  ...  0.108925
# R_POTEMP    -0.832860  0.850996     0.796164  0.750477  ...  0.103471
# R_SALINITY   0.601935 -0.787684    -0.821682 -0.693374  ... -0.029370
# R_SIGMA      0.961894 -0.929022    -0.890203 -0.434736  ... -0.084611
# R_SVA       -0.863456  0.926888     0.887058  0.761600  ...  0.080562
# R_DYNHT      0.703216 -0.775361    -0.767216 -0.729307  ... -0.297160
# R_O2        -0.889568  0.993215     0.999997  0.744969  ...  0.269652
# R_O2Sat     -0.929107  0.999999     0.993352  0.755909  ...  0.250566
# R_SIO3       0.864652 -0.890059    -0.894687 -0.744148  ... -0.177704
# R_PO4        0.948210 -0.984223    -0.974889 -0.764358  ... -0.179295
# R_NO3        0.958110 -0.983084    -0.970844 -0.761371  ... -0.187837
# R_NO2       -0.107891  0.170200     0.190172  0.065561  ...  0.197818
# R_NH4       -0.126025  0.164364     0.169454  0.026592  ...  0.182351
# R_CHLA      -0.084765  0.250458     0.272914 -0.007772  ...  1.000000
# R_PHAEO      0.008732  0.126179     0.154766 -0.055554  ...  0.695122
# R_PRES       0.581409 -0.593737    -0.587319 -0.681136  ... -0.279432
# R_SAMP      -0.005269  0.048253     0.052953  0.080356  ... -0.009154
# DIC1         0.964594 -0.985445    -0.977329 -0.888061  ... -0.235065
# DIC2         0.965546 -0.962977    -0.941528 -0.958549  ...  0.024819
# TA1          0.779899 -0.788291    -0.802435 -0.737828  ...  0.006186
# TA2          0.887778 -0.767766    -0.727023 -0.828905  ...  0.265152
# pH2         -0.480397  0.732628     0.180058 -0.457365  ...  0.047099
# pH1         -0.717815  0.913807     0.666715  0.333808  ... -0.252746
#
#               R_PHAEO    R_PRES    R_SAMP      DIC1          DIC2       TA1  \
# Cst_Cnt     -0.040576 -0.161961 -0.604945 -0.036155 -9.793799e-02 -0.075060
# Btl_Cnt     -0.035778 -0.161348 -0.595142 -0.035516 -9.725130e-02 -0.074255
# Depthm      -0.201450  0.999994 -0.018605  0.567855  5.723744e-01  0.786873
# T_degC       0.014987 -0.679852  0.006503 -0.936239 -9.499725e-01 -0.742196
# Salnty      -0.003063  0.571405 -0.000758  0.938153  9.559417e-01  0.895124
# O2ml_L       0.151917 -0.590598  0.053971 -0.977188 -9.412140e-01 -0.802493
# STheta       0.008732  0.581409 -0.005269  0.964594  9.655464e-01  0.779899
# O2Sat        0.126179 -0.593737  0.048253 -0.985445 -9.629766e-01 -0.788291
# Oxy_µmol/Kg  0.154766 -0.587319  0.052953 -0.977329 -9.415277e-01 -0.802435
# BtlNum      -0.055554 -0.681136  0.080356 -0.888061 -9.585493e-01 -0.737828
# RecInd      -0.048023  0.082183  0.031389 -0.002399           NaN -0.020875
# T_prec       0.009525  0.019445  0.006224 -0.035960           NaN -0.027074
# T_qual       0.278958 -0.255903  0.135275       NaN           NaN       NaN
# S_prec      -0.000567  0.006009 -0.011067       NaN           NaN       NaN
# S_qual       0.374864  0.143891  0.091432       NaN           NaN       NaN
# P_qual            NaN  0.000772 -0.560725       NaN           NaN       NaN
# O_qual       0.263155  0.006664 -0.108101       NaN           NaN       NaN
# SThtaq       0.333991  0.071492  0.952843 -0.259228           NaN -0.087548
# O2Satq       0.243536  0.017832 -0.217379  0.057059  3.104954e-01  0.007001
# ChlorA       0.695122 -0.279419 -0.009048 -0.235004  2.470977e-02  0.006246
# Chlqua       0.088709  0.006739 -0.027738       NaN           NaN       NaN
# Phaeop       0.999997 -0.201615  0.000997 -0.144966  2.201099e-01 -0.010653
# Phaqua      -0.021548  0.006926 -0.024079       NaN           NaN       NaN
# PO4uM       -0.071855  0.665547 -0.040689  0.995253  9.803474e-01  0.827508
# PO4q         0.008761 -0.000520 -0.015503       NaN           NaN       NaN
# SiO3uM      -0.096659  0.844771 -0.035661  0.911175  9.011417e-01  0.953625
# SiO3qu       0.012805 -0.004026  0.009242       NaN           NaN       NaN
# NO2uM        0.378518 -0.157908 -0.006400 -0.042602 -2.423986e-01 -0.027535
# NO2q         0.070331  0.011415  0.517827 -0.110800 -3.762512e-01 -0.082429
# NO3uM       -0.092927  0.685734 -0.035682  0.978738  9.815830e-01  0.792275
# ...               ...       ...       ...       ...           ...       ...
# DarkAp      -0.185275  0.064277  0.050473  0.108226           NaN  0.361539
# DarkAq      -0.001744  0.001857       NaN       NaN           NaN       NaN
# MeanAs       0.487438 -0.261924 -0.004941  0.100801  2.191560e-01  0.355443
# MeanAp      -0.101389  0.613278 -0.038421  0.303375 -1.524335e-01 -0.251212
# MeanAq      -0.001612  0.001996 -0.002027       NaN           NaN       NaN
# LightP      -0.133571 -0.471488  0.245546 -0.459389  3.767861e-14  0.321037
# R_Depth     -0.201450  0.999994 -0.018640  0.567855  5.723744e-01  0.786873
# R_TEMP       0.014987 -0.679852  0.006457 -0.936235 -9.499641e-01 -0.742189
# R_POTEMP     0.001946 -0.677652  0.006828 -0.936428 -9.492513e-01 -0.744536
# R_SALINITY  -0.003063  0.569962 -0.000935  0.938149  9.559461e-01  0.895124
# R_SIGMA      0.008726  0.604911 -0.010817  0.964595  9.655451e-01  0.779898
# R_SVA       -0.012446 -0.667728  0.001437 -0.962138 -9.643368e-01 -0.772457
# R_DYNHT     -0.214988  0.926071 -0.042668  0.796842  7.827490e-01  0.880670
# R_O2         0.151909 -0.590598  0.053889 -0.977230 -9.412144e-01 -0.802422
# R_O2Sat      0.126375 -0.594883  0.049011 -0.985443 -9.629811e-01 -0.788294
# R_SIO3      -0.096649  0.844775 -0.035706  0.911173  9.011385e-01  0.953619
# R_PO4       -0.071843  0.665553 -0.040673  0.995253  9.803474e-01  0.827508
# R_NO3       -0.092914  0.685738 -0.035732  0.978737  9.815706e-01  0.792265
# R_NO2        0.378497 -0.157923 -0.007189 -0.042822 -2.413436e-01 -0.027797
# R_NH4        0.292757 -0.164289 -0.012160 -0.235061 -3.154171e-01 -0.180469
# R_CHLA       0.695122 -0.279432 -0.009154 -0.235065  2.481911e-02  0.006186
# R_PHAEO      1.000000 -0.201600  0.000432 -0.144779  2.201011e-01 -0.010690
# R_PRES      -0.201600  1.000000 -0.019267  0.565724  5.706329e-01  0.785334
# R_SAMP       0.000432 -0.019267  1.000000 -0.008675 -2.691238e-02  0.025613
# DIC1        -0.144779  0.565724 -0.008675  1.000000  9.910913e-01  0.853682
# DIC2         0.220101  0.570633 -0.026912  0.991091  1.000000e+00  0.885735
# TA1         -0.010690  0.785334  0.025613  0.853682  8.857355e-01  1.000000
# TA2          0.235116  0.865140  0.020177  0.883278  8.886692e-01  0.994924
# pH2          0.049127  0.223304 -0.457365       NaN           NaN  0.616844
# pH1         -0.525839 -0.611798  0.333808       NaN           NaN  0.260047
#
#                       TA2       pH2       pH1
# Cst_Cnt     -1.152121e-01 -0.262587  0.020778
# Btl_Cnt     -1.141653e-01 -0.259082  0.020315
# Depthm       8.661849e-01  0.223304 -0.611798
# T_degC      -8.896354e-01  0.547436  0.743735
# Salnty       9.371469e-01  0.583807  0.106417
# O2ml_L      -7.264598e-01  0.174204  0.663591
# STheta       8.877780e-01 -0.480397 -0.717815
# O2Sat       -7.677661e-01  0.732628  0.913807
# Oxy_µmol/Kg -7.270233e-01  0.180058  0.666715
# BtlNum      -8.289052e-01 -0.457365  0.333808
# RecInd                NaN       NaN  0.029312
# T_prec                NaN       NaN       NaN
# T_qual                NaN       NaN       NaN
# S_prec                NaN       NaN       NaN
# S_qual                NaN       NaN       NaN
# P_qual                NaN       NaN       NaN
# O_qual                NaN       NaN       NaN
# SThtaq                NaN       NaN       NaN
# O2Satq       1.471229e-01       NaN       NaN
# ChlorA       2.650718e-01  0.049734 -0.252642
# Chlqua                NaN       NaN       NaN
# Phaeop       2.356047e-01  0.042505 -0.526072
# Phaqua                NaN       NaN       NaN
# PO4uM        8.192310e-01 -0.843087 -0.963169
# PO4q                  NaN       NaN       NaN
# SiO3uM       9.844488e-01 -0.332629 -0.931670
# SiO3qu                NaN       NaN       NaN
# NO2uM       -2.596418e-01 -0.237752 -0.764600
# NO2q        -3.939062e-01       NaN  0.158233
# NO3uM        8.495230e-01  0.231114 -0.898159
# ...                   ...       ...       ...
# DarkAp                NaN       NaN       NaN
# DarkAq                NaN       NaN       NaN
# MeanAs       4.214573e-01       NaN -0.143480
# MeanAp       5.196555e-03       NaN       NaN
# MeanAq                NaN       NaN       NaN
# LightP      -2.917335e-14       NaN  0.796157
# R_Depth      8.661849e-01  0.223304 -0.611798
# R_TEMP      -8.896193e-01  0.546696  0.743769
# R_POTEMP    -8.927318e-01  0.546696  0.743702
# R_SALINITY   9.371618e-01  0.583260  0.106173
# R_SIGMA      8.877732e-01 -0.479988 -0.717834
# R_SVA       -8.827830e-01  0.480163  0.716477
# R_DYNHT      9.611287e-01  0.336146 -0.509870
# R_O2        -7.264589e-01  0.171664  0.663338
# R_O2Sat     -7.677803e-01  0.733168  0.913789
# R_SIO3       9.844563e-01 -0.352025 -0.931544
# R_PO4        8.192310e-01 -0.843087 -0.963169
# R_NO3        8.495144e-01  0.189544 -0.898382
# R_NO2       -2.594867e-01 -0.260208 -0.763745
# R_NH4       -2.716047e-01 -0.092430 -0.621735
# R_CHLA       2.651516e-01  0.047099 -0.252746
# R_PHAEO      2.351158e-01  0.049127 -0.525839
# R_PRES       8.651397e-01  0.223304 -0.611798
# R_SAMP       2.017715e-02 -0.457365  0.333808
# DIC1         8.832784e-01       NaN       NaN
# DIC2         8.886692e-01       NaN       NaN
# TA1          9.949239e-01  0.616844  0.260047
# TA2          1.000000e+00  0.578090  0.577613
# pH2          5.780896e-01  1.000000  0.995913
# pH1          5.776130e-01  0.995913  1.000000
#
# [70 rows x 70 columns]

# %% [markdown]
# # Extracting Dependent and Independent Feature from Data set
#
# -> Dependent Feature/Variable, y = Salinity in g of salt per kg of water (g/kg) ( Salnty )
#
# -> Independent Feature/Variable, x = Temperature ( T_degC )

# %%
model_data = original_data[['T_degC','Salnty']]
model_data .head(5)
# Out:
#    T_degC  Salnty
# 0   10.50  33.440
# 1   10.46  33.440
# 2   10.46  33.437
# 3   10.45  33.420
# 4   10.45  33.421

# %%
model_data .shape
# Out:
# (864863, 2)

# %% [markdown]
# ### Null Values in Dependent and Independent Variable
#
# We check null values using **.isnull** & **.sum()**

# %%
print( f"Number of Null Vaues in Dependent Featrure is \n { model_data[['T_degC']] .isnull() .sum() }" )
# Out:
# Number of Null Vaues in Dependent Featrure is
#  T_degC    10963
# dtype: int64

# %%
print( f"Number of Null Vaues in Independent Feature is \n { model_data[['Salnty']] .isnull() .sum() }" )
# Out:
# Number of Null Vaues in Independent Feature is
#  Salnty    47354
# dtype: int64

# %% [markdown]
# ### Since there are 10963 null values in Dependent Feature and 47354 null values in Independent Feature
#
# For better Model and Analysis, we drop the null values using **dropna()** function and store non null values in same variables

# %%
model_data = model_data .dropna()

# %%
print( f"New shape of Model Data after dropping null Values : {model_data.shape}")
# Out:
# New shape of Model Data after dropping null Values : (814247, 2)

# %% [markdown]
# ### Now we separate Dependent & Independent Feature in x & y variable

# %%
x = model_data[['T_degC']] .values
y = model_data['Salnty'] .values

# %%
print( x[0:5] )
print( f"Shape of Independent(x) variable is { x.shape }" )
# Out:
# [[10.5 ]
#  [10.46]
#  [10.46]
#  [10.45]
#  [10.45]]
# Shape of Independent(x) variable is (814247, 1)

# %%
print( y[0:5] )
print( f"Shape of Dependent(y) variable is { y.shape }" )
# Out:
# [33.44  33.44  33.437 33.42  33.421]
# Shape of Dependent(y) variable is (814247,)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Histogram

# %%
plt.hist(model_data['Salnty'],color='orange')
plt.xlim([31,37])
plt.xlabel("Salinity in g/kg",fontsize=12)
plt.title("Salinity Histogram",fontsize=15)
plt.show()

# %%
plt.hist(model_data['T_degC'],color='green')
plt.xlabel("Temperature in C",fontsize=12)
plt.title("Temperature Histogram",fontsize=15)
plt.show()

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# -> Temperature and Salinity

# %%
plt.scatter(x,y)
plt.xlabel("Temperature")
plt.ylabel("Salinity")
plt.title("Temperature vs Salinity",loc="Center")
plt.show()

# %% [markdown]
# ### Salinty Distribution

# %%
plt.title('Salinity Distribution (g/Kg)', fontsize=14)
sns.distplot(model_data['Salnty'], color='darkgreen')
plt.show()

# %% [markdown]
# Above Distribution graph has unnecessary range on x-axis. So, we use **.xlim()** function to get better visualization

# %%
plt.figure(figsize=(8,6))
plt.xlim([32, 36])
plt.title('Salinity Distribution (g/Kg)', fontsize=14)
sns.distplot(model_data['Salnty'], color='darkgreen')
plt.show()

# %% [markdown]
# # Model Algorithm Starts

# %% [markdown]
# ### First we split our data in train and test using train_test_split function

# %%
train_x , test_x , train_y , test_y = train_test_split( x , y , test_size = 0.25 )

# %%
print("Size of Train and Test Varibales. ")
print()
print( f"Size of train_x : {train_x .shape} and test_x : {test_x .shape}" )
print( f"Size of train_y : {train_y .shape} and test_y : {test_y .shape}" )
# Out:
# Size of Train and Test Varibales.
#
# Size of train_x : (610685, 1) and test_x : (203562, 1)
# Size of train_y : (610685,) and test_y : (203562,)

# %% [markdown]
# Scatter Plot of the train and test Data set

# %%
fig = plt.figure(figsize=(9,6)) 

plt1 = fig.add_subplot(221) 
plt2 = fig.add_subplot(222) 


plt1.scatter(train_x, train_y, color ='r') 
plt1.set_title('Train x vs y') 

plt2.scatter(test_x, test_y, color ='b') 
plt2.set_title('test x vs y') 

plt.show()

# %% [markdown]
# ### We import Linear Regression model from linear_model Module

# %%
LReg = linear_model .LinearRegression()

# %% [markdown]
# ### Now we fit LReg model using train set

# %%
LReg .fit( train_x , train_y )
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Now LReg Model is ready.
#
# We get linear coefficient (Slope) and y-intercept of the Best fit line of the model

# %%
print( f"Coefficient is {LReg.coef_[0]}" )
print( f"Y-intercept is {LReg.intercept_}" )
# Out:
# Coefficient is -0.05529776007188992
# Y-intercept is 34.44184829467626

# %% [markdown]
# ### Predicting Vaues for test_x

# %%
pred_y=LReg.predict(test_x)

# %% [markdown]
# Comparing some values of Actual test y and predicted y.

# %%
comp_df = pd.DataFrame({'Actual values':test_y,'Predicted values':pred_y})
comp_df.head(10)
# Out:
#    Actual values  Predicted values
# 0         33.452         33.675974
# 1         33.990         33.275066
# 2         33.710         33.995042
# 3         34.390         34.065271
# 4         34.770         33.657726
# 5         33.096         33.643736
# 6         34.201         34.091813
# 7         32.959         33.699199
# 8         34.452         34.202962
# 9         33.610         33.914308

# %% [markdown]
# ### Visualizing the train data , test data and complete data with best fit line

# %%
fig = plt.figure(figsize=(12,10)) 

plt1 = fig.add_subplot(221) 
plt2 = fig.add_subplot(222) 


plt1.scatter(train_x, train_y, color ='r',label = 'Actual') 
plt1.plot(train_x, LReg.predict(train_x), color= 'b', label = 'Predicted')
plt1.set_title('Train x vs y')
plt1.legend()


plt2.scatter(test_x, test_y, color ='r',label = 'Actual') 
plt2.plot(test_x, LReg.predict(test_x), color= 'b', label = 'Predicted')
plt2.set_title('Test x vs y')
plt2.legend()


plt.show()
# Out:
# C:\Users\SS\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,8)) 
plt.scatter(x, y, label = 'Actual')
plt.plot(x, LReg.predict(x), color= 'red', label = 'Predicted')
plt.xlabel('Temperature', fontsize = 20)
plt.ylabel('Salinity (g/kg)', fontsize = 20)
plt.title('Predicted and Actual Salinity', fontsize = 15)
plt.legend()
# Out:
# C:\Users\SS\Anaconda3\lib\site-packages\IPython\core\events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\SS\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Evaluation of LReg Model

# %% [markdown]
# Here, we evaluate the model using some error function and score functions

# %%
LReg.score(train_x,train_y)
# Out:
# 0.25594067417996136

# %%
r2s = r2_score(test_y,pred_y)
print( f"r2 Score is {r2s}")
# Out:
# r2 Score is 0.2533518769591825

# %%
mae = mean_absolute_error(test_y,pred_y)
print( f"Mean Absolute Error is {mae}")
# Out:
# Mean Absolute Error is 0.27953594116030417

# %%
mse = mean_squared_error(test_y,pred_y)
print( f"Mean Squared Error is {mse}")
# Out:
# Mean Squared Error is 0.159232601571436

# %%
me = max_error(test_y,pred_y)
print( f"Max Error is {me}")
# Out:
# Max Error is 5.186358692004379

# %%
error_df = pd.DataFrame({'r2 score': r2s , 'Mean Absolute Error' : mae , 'Mean Squared Error' : mse , 'Max Error' : me},index=[0])
error_df
# Out:
#    r2 score  Mean Absolute Error  Mean Squared Error  Max Error
# 0  0.253352             0.279536            0.159233   5.186359

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### From above table it is clear that this LReg Model .i.e., Univariate Linear Regression is not best for this Dataset or to predict Salinity of water on basis of only Temperature.
