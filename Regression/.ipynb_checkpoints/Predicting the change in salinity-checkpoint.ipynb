# %% [markdown]
# # Data set Context
#
# The CalCOFI data set represents the longest (1949-present) and most complete (more than 50,000 sampling stations) time series of oceanographic and larval fish data in the world. It includes abundance data on the larvae of over 250 species of fish; larval length frequency data and egg abundance data on key commercial species; and oceanographic and plankton data. The physical, chemical, and biological data collected at regular time and space intervals quickly became valuable for documenting climatic cycles in the California Current and a range of biological responses to them. CalCOFI research drew world attention to the biological response to the dramatic Pacific-warming event in 1957-58 and introduced the term “El Niño” into the scientific literature.
#
# The California Cooperative Oceanic Fisheries Investigations (CalCOFI) are a unique partnership of the California Department of Fish & Wildlife, NOAA Fisheries Service and Scripps Institution of Oceanography. The organization was formed in 1949 to study the ecological aspects of the sardine population collapse off California. Today our focus has shifted to the study of the marine environment off the coast of California, the management of its living resources, and monitoring the indicators of El Nino and climate change. CalCOFI conducts quarterly cruises off southern & central California, collecting a suite of hydrographic and biological data on station and underway. Data collected at depths down to 500 m include: temperature, salinity, oxygen, phosphate, silicate, nitrate and nitrite, chlorophyll, transmissometer, PAR, C14 primary productivity, phytoplankton biodiversity, zooplankton biomass, and zooplankton biodiversity.

# %% [markdown]
# # Task  :
# In this project we investigate the relationship between water salinity and Other Features. Also we predict the change of salinity based on multiple features.

# %% [markdown]
# # Imorting All Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import linear_model

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error,max_error

# %% [markdown]
# **Importing Data Set** :
# Importing dataset from downloaded file on System using Pandas package

# %%
original_data = pd .read_csv(r"C:\Users\SS\Downloads\MDS Course files\Projects\Data Sets\Salinity\bottle.csv" )
# Out:
# C:\Users\SS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (47,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
original_data .head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  ...  R_PHAEO  R_PRES  \
# 0       0   10.50  33.440     NaN  25.649    NaN  ...      NaN       0
# 1       8   10.46  33.440     NaN  25.656    NaN  ...      NaN       8
# 2      10   10.46  33.437     NaN  25.654    NaN  ...      NaN      10
# 3      19   10.45  33.420     NaN  25.643    NaN  ...      NaN      19
# 4      20   10.45  33.421     NaN  25.643    NaN  ...      NaN      20
#
#    R_SAMP  DIC1  DIC2  TA1  TA2  pH2  pH1  DIC Quality Comment
# 0     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 1     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 2     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 3     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 4     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
#
# [5 rows x 74 columns]

# %% [markdown]
# This Shows Data has 74 columns. But we dont know the no. of entries. So, We find **SHAPE** of the data

# %%
original_data .shape
# Out:
# (864863, 74)

# %% [markdown]
# This dataset has 864863 enteries/rows and 74 features/columns

# %% [markdown]
# ### Info on features/columns of the Data set

# %%
original_data .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 74 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              864863 non-null  int64
#  1   Btl_Cnt              864863 non-null  int64
#  2   Sta_ID               864863 non-null  object
#  3   Depth_ID             864863 non-null  object
#  4   Depthm               864863 non-null  int64
#  5   T_degC               853900 non-null  float64
#  6   Salnty               817509 non-null  float64
#  7   O2ml_L               696201 non-null  float64
#  8   STheta               812174 non-null  float64
#  9   O2Sat                661274 non-null  float64
#  10  Oxy_µmol/Kg          661268 non-null  float64
#  11  BtlNum               118667 non-null  float64
#  12  RecInd               864863 non-null  int64
#  13  T_prec               853900 non-null  float64
#  14  T_qual               23127 non-null   float64
#  15  S_prec               817509 non-null  float64
#  16  S_qual               74914 non-null   float64
#  17  P_qual               673755 non-null  float64
#  18  O_qual               184676 non-null  float64
#  19  SThtaq               65823 non-null   float64
#  20  O2Satq               217797 non-null  float64
#  21  ChlorA               225272 non-null  float64
#  22  Chlqua               639166 non-null  float64
#  23  Phaeop               225271 non-null  float64
#  24  Phaqua               639170 non-null  float64
#  25  PO4uM                413317 non-null  float64
#  26  PO4q                 451786 non-null  float64
#  27  SiO3uM               354091 non-null  float64
#  28  SiO3qu               510866 non-null  float64
#  29  NO2uM                337576 non-null  float64
#  30  NO2q                 529474 non-null  float64
#  31  NO3uM                337403 non-null  float64
#  32  NO3q                 529933 non-null  float64
#  33  NH3uM                64962 non-null   float64
#  34  NH3q                 808299 non-null  float64
#  35  C14As1               14432 non-null   float64
#  36  C14A1p               12760 non-null   float64
#  37  C14A1q               848605 non-null  float64
#  38  C14As2               14414 non-null   float64
#  39  C14A2p               12742 non-null   float64
#  40  C14A2q               848623 non-null  float64
#  41  DarkAs               22649 non-null   float64
#  42  DarkAp               20457 non-null   float64
#  43  DarkAq               840440 non-null  float64
#  44  MeanAs               22650 non-null   float64
#  45  MeanAp               20457 non-null   float64
#  46  MeanAq               840439 non-null  float64
#  47  IncTim               14437 non-null   object
#  48  LightP               18651 non-null   float64
#  49  R_Depth              864863 non-null  float64
#  50  R_TEMP               853900 non-null  float64
#  51  R_POTEMP             818816 non-null  float64
#  52  R_SALINITY           817509 non-null  float64
#  53  R_SIGMA              812007 non-null  float64
#  54  R_SVA                812092 non-null  float64
#  55  R_DYNHT              818206 non-null  float64
#  56  R_O2                 696201 non-null  float64
#  57  R_O2Sat              666448 non-null  float64
#  58  R_SIO3               354099 non-null  float64
#  59  R_PO4                413325 non-null  float64
#  60  R_NO3                337411 non-null  float64
#  61  R_NO2                337584 non-null  float64
#  62  R_NH4                64982 non-null   float64
#  63  R_CHLA               225276 non-null  float64
#  64  R_PHAEO              225275 non-null  float64
#  65  R_PRES               864863 non-null  int64
#  66  R_SAMP               122006 non-null  float64
#  67  DIC1                 1999 non-null    float64
#  68  DIC2                 224 non-null     float64
#  69  TA1                  2084 non-null    float64
#  70  TA2                  234 non-null     float64
#  71  pH2                  10 non-null      float64
#  72  pH1                  84 non-null      float64
#  73  DIC Quality Comment  55 non-null      object
# dtypes: float64(65), int64(5), object(4)
# memory usage: 488.3+ MB

# %% [markdown]
# Result of this code shows 65 features are of float data type , 5 are of int data type and 4 are objects.

# %% [markdown]
# ### Statistical Information of the Data set

# %%
original_data .describe()

# %% [markdown]
# # Null Values

# %%
original_data.isnull().sum()

# %% [markdown]
# Clearly there many features which have only nan values.
# So we need drop these features which has more than 3,00,000 null values

# %%
# We drop columns/features with more than 300000 nan values

data_wo_null = original_data.dropna(axis = 'columns' , thresh = 500000)

# %%
# To check new shape of the data
data_wo_null.shape

# %% [markdown]
# ### Now we drop null values from rows

# %%
data_wo_nan = data_wo_null.dropna()

# %%
data_wo_nan.shape

# %% [markdown]
# # Correlation

# %% [markdown]
# We find correlation between features which have numerical values or which are not object dtypes.

# %%
cont_features = data_wo_nan.select_dtypes(exclude='object')

# %%
plt.figure(figsize=(30,30))
sns.heatmap(data=cont_features.corr(method='pearson'), annot=True)
plt.show()

# %% [markdown]
# ### From this correlation matrrix , we have multiple features on which salinity of water is depending.

# %% [markdown]
# # Feature Selection
# First we have 73 features but after droping features with alot of nan values and object dtype fetaures we left with 33 features. So, we need to select top 10 features which affect Salinty of water maximum

# %%
features = cont_features.loc[:, cont_features.columns != 'Salnty']

# %%
target = cont_features.loc[:,cont_features.columns=='Salnty']

# %% [markdown]
# ### We have alot of features. So we try to sort them to reduce computation power and we choose best features which are mostly affecting our target.

# %% [markdown]
# ### For Feature Selection we use Annova function in SelectKBest
# First we import some functions from modules of some packages

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

# %%
bestfeatures = SelectKBest(score_func = f_classif,k = 'all')

# %%
fit = bestfeatures.fit(features,target)
feature_scores = pd.DataFrame(fit.scores_)

# %%
feature_column_name=pd.DataFrame(features.columns)
feature_score_df = pd.concat([feature_column_name,feature_scores],axis=1)
feature_score_df.columns=['Features','Score']
feature_score_df

# %% [markdown]
# ### Top 10 Features with best scores

# %%
print(feature_score_df.nlargest(10,'Score'))

# %%
a = feature_score_df.nlargest(10,'Score')
[x for x in a['Features']]

# %% [markdown]
# # Model Dataset

# %%
model_data = cont_features[['R_SALINITY', 'O2ml_L', 'R_O2', 'Oxy_µmol/Kg', 'S_prec', 'O2Sat', 'R_O2Sat', 'R_DYNHT', 'Depthm', 
                            'R_Depth','Salnty']]
model_data .head(5)

# %% [markdown]
# # Extracting Dependent and Independent Feature from Data set

# %% [markdown]
# ## First we check multicollinearity between Features
# **We check and confirme multicollinearity by Ordinary Least Square model and Correlation between the. Then we drop those features based on the p value of Ordinary Least Square Model (OLS).**

# %% [markdown]
# ### OLS

# %%
import statsmodels.api as sm

# %%
X = model_data[['R_SALINITY', 'O2ml_L', 'R_O2', 'Oxy_µmol/Kg', 'S_prec', 'O2Sat','R_O2Sat', 'R_DYNHT', 'Depthm', 'R_Depth']]
Y = model_data['Salnty']

# %%
X = sm.add_constant(X)

# %%
OLS_model= sm.OLS(Y, X).fit()

# %%
OLS_model.summary()

# %% [markdown]
# ### Correlation Matrix of the features of the Model Dataset

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data=model_data.corr(), annot=True)

# %% [markdown]
# ### Clearly from p value of OLS Model and Correlation Matrix, features like 'O2ml_L', 'R_O2', 'O2Sat','R_O2Sat', 'R_DYNHT' are highly correlated to each other. Finally we drop them to start modeling.

# %%
x = model_data[['Oxy_µmol/Kg','S_prec','Depthm']].values

# %%
y = model_data['Salnty'].values

# %%
print( x[0:5] )
print( f"Shape of Independent(x) variable is { x.shape }" )

# %%
print( y[0:5] )
print( f"Shape of Dependent(y) variable is { y.shape }" )

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Since here we have multiple features on which salinity of water depends. So, we make pair plot which shows scatter plot with continuos features.

# %%
sns.pairplot(model_data)
plt.show()

# %%
model_data.hist(layout=(3,4),figsize=(15,10))
plt.show()

# %% [markdown]
# ### Salinity Distribution

# %%
plt.figure(figsize=(8,6))
plt.xlim([32, 36])
plt.title('Salinity Distribution (g/Kg)', fontsize=14)
sns.distplot(model_data['Salnty'], color='darkgreen')
plt.show()

# %% [markdown]
# ### Histogram

# %%
plt.hist(model_data['Salnty'],color='orange')
plt.xlim([31,37])
plt.xlabel("Salinity in g/kg",fontsize=12)
plt.title("Salinity Histogram",fontsize=15)
plt.show()

# %%
model_data.plot(kind='box',layout=(3,4), subplots=True, figsize=(15,10))
plt.show()

# %% [markdown]
# # Model Algorithm Starts

# %% [markdown]
# In this model, there are multiple independent features. Also, each independent feature has different range.So, we need to make equal range for all independent features.
# Also, there are many features which have many outliers.
#
# To remove these problems, we use **standard scalar** from **preprocessing** module to rescale all features.

# %%
x = preprocessing.StandardScaler().fit(x).transform(x) 
x[0:5]

# %% [markdown]
# ### Now we split our data in train and test using train_test_split function

# %%
train_x , test_x , train_y , test_y = train_test_split( x , y , test_size = 0.25 )

# %%
print("Size of Train and Test Varibales. ")
print()
print( f"Size of train_x : {train_x .shape} and test_x : {test_x .shape}" )
print( f"Size of train_y : {train_y .shape} and test_y : {test_y .shape}" )

# %% [markdown]
# ### We import Linear Regression model from linear_model Module

# %%
MVLReg = linear_model .LinearRegression()

# %% [markdown]
# ### Now we fit MVLReg model using train set

# %%
MVLReg .fit( train_x , train_y )

# %% [markdown]
# ### Now MVLReg Model is ready.
#
# We get linear coefficients (Slope) and y-intercept of the Best fit line of the model

# %%
print( f"Coefficients are {MVLReg.coef_}" )
print( f"Y-intercept is {MVLReg.intercept_}" )

# %% [markdown]
# ### Predicting Vaues for test_x

# %%
pred_y=MVLReg.predict(test_x)

# %% [markdown]
# Comparing some values of Actual test y and predicted y.

# %%
comp_df = pd.DataFrame({'Actual values':test_y,'Predicted values':pred_y})
comp_df.head()

# %% [markdown]
# # Evaluation of MVLReg Model

# %% [markdown]
# Here, we evaluate the model using some error function and score functions

# %%
MVLReg.score(train_x,train_y)

# %%
r2s = r2_score(test_y,pred_y)
print( f"r2 Score is {r2s}")

# %%
mae = mean_absolute_error(test_y,pred_y)
print( f"Mean Absolute Error is {mae}")

# %%
rmse = np.sqrt(mean_squared_error(test_y,pred_y))
print( f"Root Mean Squared Error is {rmse}")

# %%
error_df = pd.DataFrame({'r2 score': r2s , 'Mean Absolute Error' : mae , 'Root Mean Squared Error' : rmse },index=[0])
error_df

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### From above table it is clear that r2 score of this model is not that good to predict the salinity of the water.
#
# **We will try to model with Artificial Neural Network**

# %%
# Import all needed libraries and sublibraries

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
import sklearn
from sklearn import preprocessing

# %%
X = model_data[['Oxy_µmol/Kg','S_prec','Depthm']]
Y = model_data['Salnty'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Now we start making Artificial Neural Network

# %% [markdown]
# **First we initialize the Model**

# %%
NN_model = Sequential()

# %% [markdown]
# **Input Dense Layer with 200 neurons and relu activation function. Also he_normal is used to default initialisation of weights**

# %%
NN_model.add(Dense(200, kernel_initializer='he_normal',input_dim = X_train.shape[1], activation='relu'))

# %% [markdown]
# **4 Hidden Dense Layers are used with 256 neurons and relu activation function. For weight initializer again he_normal is used.**

# %%
NN_model.add(Dense(256, kernel_initializer='he_normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='he_normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='he_normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='he_normal',activation='relu'))

# %% [markdown]
# **Output Dense Layer is defined with single neuron and linear activation function**

# %%
NN_model.add(Dense(1, activation='linear'))

# %% [markdown]
# **To compile the Network Mean Squared Error as Loss Function, Adam as Optimizer and mean square error as metric are used.**

# %%
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

# %% [markdown]
# **Model is fitted with 100 epoches, 0.2 as validation split and 50 batch size is selected.**

# %%
Regression = NN_model.fit(X_train, y_train, epochs=100, batch_size=50, validation_split = 0.2)
# Out:
# Train on 191702 samples, validate on 47926 samples
# Epoch 1/100
# 191702/191702 [==============================] - 39s 202us/step - loss: 3.7637 - mse: 3.7637 - val_loss: 0.6138 - val_mse: 0.6138
# Epoch 2/100
# 191702/191702 [==============================] - 38s 201us/step - loss: 0.1626 - mse: 0.1626 - val_loss: 0.1071 - val_mse: 0.1071
# Epoch 3/100
# 191702/191702 [==============================] - 43s 226us/step - loss: 0.1440 - mse: 0.1440 - val_loss: 0.0876 - val_mse: 0.0876
# Epoch 4/100
# 191702/191702 [==============================] - 41s 212us/step - loss: 0.1261 - mse: 0.1261 - val_loss: 0.1164 - val_mse: 0.1164
# Epoch 5/100
# 191702/191702 [==============================] - 41s 213us/step - loss: 0.1206 - mse: 0.1206 - val_loss: 0.0865 - val_mse: 0.0865
# Epoch 6/100
# 191702/191702 [==============================] - 42s 219us/step - loss: 0.1134 - mse: 0.1134 - val_loss: 0.1449 - val_mse: 0.1449
# Epoch 7/100
# 191702/191702 [==============================] - 41s 213us/step - loss: 0.1130 - mse: 0.1130 - val_loss: 0.1252 - val_mse: 0.1252
# Epoch 8/100
# 191702/191702 [==============================] - 41s 214us/step - loss: 0.1048 - mse: 0.1048 - val_loss: 0.1368 - val_mse: 0.1368
# Epoch 9/100
# 191702/191702 [==============================] - 41s 213us/step - loss: 0.1031 - mse: 0.1031 - val_loss: 0.2879 - val_mse: 0.2879
# Epoch 10/100
# 191702/191702 [==============================] - 40s 208us/step - loss: 0.1030 - mse: 0.1030 - val_loss: 0.0879 - val_mse: 0.0879
# Epoch 11/100
# 191702/191702 [==============================] - 40s 208us/step - loss: 0.1011 - mse: 0.1011 - val_loss: 0.2189 - val_mse: 0.2189
# Epoch 12/100
# 191702/191702 [==============================] - 43s 223us/step - loss: 0.0998 - mse: 0.0998 - val_loss: 0.1512 - val_mse: 0.1512
# Epoch 13/100
# 191702/191702 [==============================] - 47s 245us/step - loss: 0.0969 - mse: 0.0969 - val_loss: 0.0751 - val_mse: 0.0751
# Epoch 14/100
# 191702/191702 [==============================] - 41s 212us/step - loss: 0.0959 - mse: 0.0959 - val_loss: 0.8520 - val_mse: 0.8520
# Epoch 15/100
# 191702/191702 [==============================] - 40s 207us/step - loss: 0.0947 - mse: 0.0947 - val_loss: 0.1896 - val_mse: 0.1896
# Epoch 16/100
# 191702/191702 [==============================] - 38s 199us/step - loss: 0.0929 - mse: 0.0929 - val_loss: 0.0856 - val_mse: 0.0856
# Epoch 17/100
# 191702/191702 [==============================] - 41s 215us/step - loss: 0.0928 - mse: 0.0928 - val_loss: 0.1102 - val_mse: 0.1102
# Epoch 18/100
# 191702/191702 [==============================] - 40s 208us/step - loss: 0.0916 - mse: 0.0916 - val_loss: 0.1872 - val_mse: 0.1872
# Epoch 19/100
# 191702/191702 [==============================] - 39s 205us/step - loss: 0.0912 - mse: 0.0912 - val_loss: 0.0696 - val_mse: 0.0696
# Epoch 20/100
# 191702/191702 [==============================] - 40s 209us/step - loss: 0.0889 - mse: 0.0889 - val_loss: 0.0748 - val_mse: 0.0748
# Epoch 21/100
# 191702/191702 [==============================] - 39s 201us/step - loss: 0.0897 - mse: 0.0897 - val_loss: 0.3001 - val_mse: 0.3001
# Epoch 22/100
# 191702/191702 [==============================] - 41s 212us/step - loss: 0.0885 - mse: 0.0885 - val_loss: 0.0836 - val_mse: 0.0836
# Epoch 23/100
# 191702/191702 [==============================] - 39s 205us/step - loss: 0.0886 - mse: 0.0886 - val_loss: 0.1304 - val_mse: 0.1304
# Epoch 24/100
# 191702/191702 [==============================] - 39s 206us/step - loss: 0.0874 - mse: 0.0874 - val_loss: 0.0761 - val_mse: 0.0761
# Epoch 25/100
# 191702/191702 [==============================] - 38s 201us/step - loss: 0.0869 - mse: 0.0869 - val_loss: 0.0916 - val_mse: 0.0916
# Epoch 26/100
# 191702/191702 [==============================] - 39s 203us/step - loss: 0.0864 - mse: 0.0864 - val_loss: 0.0709 - val_mse: 0.0709
# Epoch 27/100
# 191702/191702 [==============================] - 38s 197us/step - loss: 0.0852 - mse: 0.0852 - val_loss: 0.0874 - val_mse: 0.0874
# Epoch 28/100
# 191702/191702 [==============================] - 40s 208us/step - loss: 0.0862 - mse: 0.0862 - val_loss: 0.5001 - val_mse: 0.5001
# Epoch 29/100
# 191702/191702 [==============================] - 38s 197us/step - loss: 0.0860 - mse: 0.0860 - val_loss: 0.1823 - val_mse: 0.1823
# Epoch 30/100
# 191702/191702 [==============================] - 39s 203us/step - loss: 0.0853 - mse: 0.0853 - val_loss: 0.0716 - val_mse: 0.0716
# Epoch 31/100
# 191702/191702 [==============================] - 39s 204us/step - loss: 0.0853 - mse: 0.0853 - val_loss: 0.0732 - val_mse: 0.0732
# Epoch 32/100
# 191702/191702 [==============================] - 42s 217us/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0774 - val_mse: 0.0774
# Epoch 33/100
# 191702/191702 [==============================] - 40s 207us/step - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0821 - val_mse: 0.0821
# Epoch 34/100
# 191702/191702 [==============================] - 40s 210us/step - loss: 0.0832 - mse: 0.0832 - val_loss: 0.0784 - val_mse: 0.0784
# Epoch 35/100
# 191702/191702 [==============================] - 40s 208us/step - loss: 0.0825 - mse: 0.0825 - val_loss: 0.0716 - val_mse: 0.0716
# Epoch 36/100
# 191702/191702 [==============================] - 39s 202us/step - loss: 0.0831 - mse: 0.0831 - val_loss: 0.0744 - val_mse: 0.0744
# Epoch 37/100
# 191702/191702 [==============================] - 39s 205us/step - loss: 0.0821 - mse: 0.0821 - val_loss: 0.1362 - val_mse: 0.1362
# Epoch 38/100
# 191702/191702 [==============================] - 40s 208us/step - loss: 0.0822 - mse: 0.0822 - val_loss: 0.0763 - val_mse: 0.0763
# Epoch 39/100
# 191702/191702 [==============================] - 38s 200us/step - loss: 0.0820 - mse: 0.0820 - val_loss: 0.1500 - val_mse: 0.1500
# Epoch 40/100
# 191702/191702 [==============================] - 40s 211us/step - loss: 0.0809 - mse: 0.0809 - val_loss: 0.2115 - val_mse: 0.2115
# Epoch 41/100
# 191702/191702 [==============================] - 40s 210us/step - loss: 0.0809 - mse: 0.0809 - val_loss: 0.0957 - val_mse: 0.0957
# Epoch 42/100
# 191702/191702 [==============================] - 42s 220us/step - loss: 0.0819 - mse: 0.0819 - val_loss: 0.0793 - val_mse: 0.0793
# Epoch 43/100
# 191702/191702 [==============================] - 46s 241us/step - loss: 0.0807 - mse: 0.0807 - val_loss: 0.0781 - val_mse: 0.0781
# Epoch 44/100
# 191702/191702 [==============================] - 43s 224us/step - loss: 0.0803 - mse: 0.0803 - val_loss: 0.0810 - val_mse: 0.0810
# Epoch 45/100
# 191702/191702 [==============================] - 41s 216us/step - loss: 0.0805 - mse: 0.0805 - val_loss: 0.0814 - val_mse: 0.0814
# Epoch 46/100
# 191702/191702 [==============================] - 42s 218us/step - loss: 0.0806 - mse: 0.0806 - val_loss: 0.1382 - val_mse: 0.1382
# Epoch 47/100
# 191702/191702 [==============================] - 45s 236us/step - loss: 0.0809 - mse: 0.0809 - val_loss: 0.0717 - val_mse: 0.0717
# Epoch 48/100
# 191702/191702 [==============================] - 44s 229us/step - loss: 0.0793 - mse: 0.0793 - val_loss: 0.0777 - val_mse: 0.0777
# Epoch 49/100
# 191702/191702 [==============================] - 46s 238us/step - loss: 0.0792 - mse: 0.0792 - val_loss: 0.1671 - val_mse: 0.1671
# Epoch 50/100
# 191702/191702 [==============================] - 45s 235us/step - loss: 0.0802 - mse: 0.0802 - val_loss: 0.0706 - val_mse: 0.0706
# Epoch 51/100
# 191702/191702 [==============================] - 42s 219us/step - loss: 0.0797 - mse: 0.0797 - val_loss: 0.0694 - val_mse: 0.0694
# Epoch 52/100
# 191702/191702 [==============================] - 42s 217us/step - loss: 0.0795 - mse: 0.0795 - val_loss: 0.1243 - val_mse: 0.1243
# Epoch 53/100
# 191702/191702 [==============================] - 41s 215us/step - loss: 0.0793 - mse: 0.0793 - val_loss: 0.0717 - val_mse: 0.0717
# Epoch 54/100
# 191702/191702 [==============================] - 41s 216us/step - loss: 0.0783 - mse: 0.0783 - val_loss: 0.0878 - val_mse: 0.0878
# Epoch 55/100
# 191702/191702 [==============================] - 41s 212us/step - loss: 0.0790 - mse: 0.0790 - val_loss: 0.1310 - val_mse: 0.1310
# Epoch 56/100
# 191702/191702 [==============================] - 41s 213us/step - loss: 0.0790 - mse: 0.0790 - val_loss: 0.0891 - val_mse: 0.0891
# Epoch 57/100
# 191702/191702 [==============================] - 41s 213us/step - loss: 0.0775 - mse: 0.0775 - val_loss: 0.0920 - val_mse: 0.0920
# Epoch 58/100
# 191702/191702 [==============================] - 41s 211us/step - loss: 0.0783 - mse: 0.0783 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 59/100
# 191702/191702 [==============================] - 41s 216us/step - loss: 0.0779 - mse: 0.0779 - val_loss: 0.0709 - val_mse: 0.0709
# Epoch 60/100
# 191702/191702 [==============================] - 41s 214us/step - loss: 0.0770 - mse: 0.0770 - val_loss: 0.1283 - val_mse: 0.1283
# Epoch 61/100
# 191702/191702 [==============================] - 42s 219us/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.1033 - val_mse: 0.1033
# Epoch 62/100
# 191702/191702 [==============================] - 42s 217us/step - loss: 0.0776 - mse: 0.0776 - val_loss: 0.0733 - val_mse: 0.0733
# Epoch 63/100
# 191702/191702 [==============================] - 41s 214us/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.1401 - val_mse: 0.1401
# Epoch 64/100
# 191702/191702 [==============================] - 42s 221us/step - loss: 0.0774 - mse: 0.0774 - val_loss: 0.0738 - val_mse: 0.0738
# Epoch 65/100
# 191702/191702 [==============================] - 41s 214us/step - loss: 0.0770 - mse: 0.0770 - val_loss: 0.0900 - val_mse: 0.0900
# Epoch 66/100
# 191702/191702 [==============================] - 41s 216us/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.0699 - val_mse: 0.0699
# Epoch 67/100
# 191702/191702 [==============================] - 43s 223us/step - loss: 0.0762 - mse: 0.0762 - val_loss: 0.0725 - val_mse: 0.0725
# Epoch 68/100
# 191702/191702 [==============================] - 38s 199us/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.0685 - val_mse: 0.0685
# Epoch 69/100
# 191702/191702 [==============================] - 39s 205us/step - loss: 0.0762 - mse: 0.0762 - val_loss: 0.0820 - val_mse: 0.0820
# Epoch 70/100
# 191702/191702 [==============================] - 39s 203us/step - loss: 0.0754 - mse: 0.0754 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 71/100
# 191702/191702 [==============================] - 38s 199us/step - loss: 0.0755 - mse: 0.0755 - val_loss: 0.0788 - val_mse: 0.0788
# Epoch 72/100
# 191702/191702 [==============================] - 38s 196us/step - loss: 0.0751 - mse: 0.0751 - val_loss: 0.0691 - val_mse: 0.0691
# Epoch 73/100
# 191702/191702 [==============================] - 38s 199us/step - loss: 0.0751 - mse: 0.0751 - val_loss: 0.0703 - val_mse: 0.0703
# Epoch 74/100
# 191702/191702 [==============================] - 38s 200us/step - loss: 0.0749 - mse: 0.0749 - val_loss: 0.0773 - val_mse: 0.0773
# Epoch 75/100
# 191702/191702 [==============================] - 38s 200us/step - loss: 0.0754 - mse: 0.0754 - val_loss: 0.0762 - val_mse: 0.0762
# Epoch 76/100
# 191702/191702 [==============================] - 39s 203us/step - loss: 0.0745 - mse: 0.0745 - val_loss: 0.2306 - val_mse: 0.2306
# Epoch 77/100
# 191702/191702 [==============================] - 38s 200us/step - loss: 0.0750 - mse: 0.0750 - val_loss: 0.1009 - val_mse: 0.1009
# Epoch 78/100
# 191702/191702 [==============================] - 38s 198us/step - loss: 0.0747 - mse: 0.0747 - val_loss: 0.0909 - val_mse: 0.0909
# Epoch 79/100
# 191702/191702 [==============================] - 38s 199us/step - loss: 0.0741 - mse: 0.0741 - val_loss: 0.0707 - val_mse: 0.0707
# Epoch 80/100
# 191702/191702 [==============================] - 38s 196us/step - loss: 0.0738 - mse: 0.0738 - val_loss: 0.0695 - val_mse: 0.0695
# Epoch 81/100
# 191702/191702 [==============================] - 38s 197us/step - loss: 0.0740 - mse: 0.0740 - val_loss: 0.0808 - val_mse: 0.0808
# Epoch 82/100
# 191702/191702 [==============================] - 38s 198us/step - loss: 0.0736 - mse: 0.0736 - val_loss: 0.0705 - val_mse: 0.0705
# Epoch 83/100
# 191702/191702 [==============================] - 38s 197us/step - loss: 0.0735 - mse: 0.0735 - val_loss: 0.0971 - val_mse: 0.0971
# Epoch 84/100
# 191702/191702 [==============================] - 38s 196us/step - loss: 0.0733 - mse: 0.0733 - val_loss: 0.0690 - val_mse: 0.0690
# Epoch 85/100
# 191702/191702 [==============================] - 37s 195us/step - loss: 0.0730 - mse: 0.0730 - val_loss: 0.0718 - val_mse: 0.0718
# Epoch 86/100
# 191702/191702 [==============================] - 38s 197us/step - loss: 0.0736 - mse: 0.0736 - val_loss: 0.0681 - val_mse: 0.0681
# Epoch 87/100
# 191702/191702 [==============================] - 39s 202us/step - loss: 0.0731 - mse: 0.0731 - val_loss: 0.0840 - val_mse: 0.0840
# Epoch 88/100
# 191702/191702 [==============================] - 38s 196us/step - loss: 0.0729 - mse: 0.0729 - val_loss: 0.0686 - val_mse: 0.0686
# Epoch 89/100
# 191702/191702 [==============================] - 38s 196us/step - loss: 0.0730 - mse: 0.0730 - val_loss: 0.1212 - val_mse: 0.1212
# Epoch 90/100
# 191702/191702 [==============================] - 38s 197us/step - loss: 0.0732 - mse: 0.0732 - val_loss: 0.0838 - val_mse: 0.0838
# Epoch 91/100
# 191702/191702 [==============================] - 64s 336us/step - loss: 0.0731 - mse: 0.0731 - val_loss: 0.0680 - val_mse: 0.0680
# Epoch 92/100
# 191702/191702 [==============================] - 45s 234us/step - loss: 0.0727 - mse: 0.0727 - val_loss: 0.0729 - val_mse: 0.0729
# Epoch 93/100
# 191702/191702 [==============================] - 41s 211us/step - loss: 0.0721 - mse: 0.0721 - val_loss: 0.0743 - val_mse: 0.0743
# Epoch 94/100
# 191702/191702 [==============================] - 40s 211us/step - loss: 0.0722 - mse: 0.0722 - val_loss: 0.0708 - val_mse: 0.0708
# Epoch 95/100
# 191702/191702 [==============================] - 42s 219us/step - loss: 0.0726 - mse: 0.0726 - val_loss: 0.1225 - val_mse: 0.1225
# Epoch 96/100
# 191702/191702 [==============================] - 40s 210us/step - loss: 0.0723 - mse: 0.0723 - val_loss: 0.0686 - val_mse: 0.0686
# Epoch 97/100
# 191702/191702 [==============================] - 40s 209us/step - loss: 0.0723 - mse: 0.0723 - val_loss: 0.0707 - val_mse: 0.0707
# Epoch 98/100
# 191702/191702 [==============================] - 43s 223us/step - loss: 0.0726 - mse: 0.0726 - val_loss: 0.0701 - val_mse: 0.0701
# Epoch 99/100
# 191702/191702 [==============================] - 41s 214us/step - loss: 0.0719 - mse: 0.0719 - val_loss: 0.0684 - val_mse: 0.0684
# Epoch 100/100
# 191702/191702 [==============================] - 40s 211us/step - loss: 0.0720 - mse: 0.0720 - val_loss: 0.0953 - val_mse: 0.0953

# %% [markdown]
# ### Since our Loss Function and Metric of accuracy is same we use a single graph to plot them.

# %% [markdown]
# ## Plotting Mean Square Error of the Model

# %%
plt.plot(Regression.history['mse'])
plt.plot(Regression.history['val_mse'])
plt.title('Model Accuracy and Loss Value')
plt.ylabel('Accuracy/Loss Value')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ## Predicting Values

# %%
y_pred = NN_model.predict(X_test)

# %% [markdown]
# ### Evaluating for Test Data

# %%
Root_Mean_Square_Error = np.sqrt(mean_squared_error(y_test,y_pred))
print( f"Root Mean Squared Error is {Root_Mean_Square_Error}")
# Out:
# Root Mean Squared Error is 0.30734872495884924

# %%
r2_Score = r2_score(y_test,y_pred)
print( f"r2 Score is {r2_Score}")
# Out:
# r2 Score is 0.5714285267769715

# %% [markdown]
# ## This ANN Model didnt increased any accuracy of the model.
