# %% [markdown]
# # Dataset Description

# %% [markdown]
# **Source :**
#
# https://archive.ics.uci.edu/ml/datasets/Individual+household+electric+power+consumption
#
#
#
# **Data Set Information:**
#
# This archive contains 2075259 measurements gathered in a house located in Sceaux (7km of Paris, France) between December 2006 and November 2010 (47 months).
#
# Notes:
# 1. (global_active_power*1000/60 - sub_metering_1 - sub_metering_2 - sub_metering_3) represents the active energy consumed every minute (in watt hour) in the household by electrical equipment not measured in sub-meterings 1, 2 and 3.
# 2. The dataset contains some missing values in the measurements (nearly 1,25% of the rows). All calendar timestamps are present in the dataset but for some timestamps, the measurement values are missing: a missing value is represented by the absence of value between two consecutive semi-colon attribute separators. For instance, the dataset shows missing values on April 28, 2007.
#
#
#
# **Attribute Information:**
#
# 1. date: Date in format dd/mm/yyyy
# 2. time: time in format hh:mm:ss
# 3. global_active_power: household global minute-averaged active power (in kilowatt)
# 4. global_reactive_power: household global minute-averaged reactive power (in kilowatt)
# 5. voltage: minute-averaged voltage (in volt)
# 6. global_intensity: household global minute-averaged current intensity (in ampere)
# 7. sub_metering_1: energy sub-metering No. 1 (in watt-hour of active energy). It corresponds to the kitchen, containing mainly a  dishwasher, an oven and a microwave (hot plates are not electric but gas powered).
# 8. sub_metering_2: energy sub-metering No. 2 (in watt-hour of active energy). It corresponds to the laundry room, containing a washing-machine, a tumble-drier, a refrigerator and a light.
# 9. sub_metering_3: energy sub-metering No. 3 (in watt-hour of active energy). It corresponds to an electric water-heater and an air-conditioner.

# %% [markdown]
# # -> Task: Our task is to forecast the Voltage and compare it with given voltage.

# %% [markdown]
# # Importing some common Packages and Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import itertools
import warnings
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Loading Dataset using pandas Package

# %%
Data = pd.read_csv("C:\\Users\\SS\\Downloads\\MDS Course files\\Data set\\household_power_consumption\\household_power_consumption.txt",sep=';')
# Out:
# C:\Users\SS\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Dataset set is in txt format and also have data separated by ';'. So, we used sep argument to make correct dataframe / tabel

# %%
Data.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %% [markdown]
# ## Checking Data Structure
# -> Number of rows / instaces / enteries
#
# -> Number of columns / features / attributes

# %%
print(f"Number of rows are {Data.shape[0]}. \nNumber of Columns are {Data.shape[1]}.")
# Out:
# Number of rows are 2075259.
# Number of Columns are 9.

# %% [markdown]
# ## Information about columns

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
# Date                     object
# Time                     object
# Global_active_power      object
# Global_reactive_power    object
# Voltage                  object
# Global_intensity         object
# Sub_metering_1           object
# Sub_metering_2           object
# Sub_metering_3           float64
# dtypes: float64(1), object(8)
# memory usage: 142.5+ MB

# %% [markdown]
# Clearly from this we can see there are many features which are numbers in real but categorised as object.
#
# So, we will change their types.

# %%
Data.columns
# Out:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %% [markdown]
# To change the types of the columns, First we seprate Date, Time and Other Features then we **use apply function and .to_numeric function**

# %%
temp1 = Data[['Date', 'Time']]
temp1.head(2)
# Out:
#          Date      Time
# 0  16/12/2006  17:24:00
# 1  16/12/2006  17:25:00

# %%
temp1[['Date']] = temp1[['Date']].apply(pd.to_datetime)
temp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 2 columns):
# Date    datetime64[ns]
# Time    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 31.7+ MB
# C:\Users\SS\Anaconda3\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
temp1.head()
# Out:
#         Date      Time
# 0 2006-12-16  17:24:00
# 1 2006-12-16  17:25:00
# 2 2006-12-16  17:26:00
# 3 2006-12-16  17:27:00
# 4 2006-12-16  17:28:00

# %%
temp2 = Data[['Global_active_power', 'Global_reactive_power','Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
              'Sub_metering_3']]
temp2.head(2)
# Out:
#   Global_active_power Global_reactive_power  Voltage Global_intensity  \
# 0               4.216                 0.418  234.840           18.400
# 1               5.360                 0.436  233.630           23.000
#
#   Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0          0.000          1.000            17.0
# 1          0.000          1.000            16.0

# %%
temp2 = temp2.apply(pd.to_numeric, errors='coerce')
temp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 7 columns):
# Global_active_power      float64
# Global_reactive_power    float64
# Voltage                  float64
# Global_intensity         float64
# Sub_metering_1           float64
# Sub_metering_2           float64
# Sub_metering_3           float64
# dtypes: float64(7)
# memory usage: 110.8 MB

# %%
Data = pd.concat([temp1,temp2],axis=1)
Data.head()
# Out:
#         Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0 2006-12-16  17:24:00                4.216                  0.418   234.84
# 1 2006-12-16  17:25:00                5.360                  0.436   233.63
# 2 2006-12-16  17:26:00                5.374                  0.498   233.29
# 3 2006-12-16  17:27:00                5.388                  0.502   233.74
# 4 2006-12-16  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %% [markdown]
# Now Data is ready with correct feature types

# %% [markdown]
# # Checking Missing Values

# %%
Data.isnull().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3           25979
# dtype: int64

#
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 6839         NaN               NaN             NaN             NaN
# 6840         NaN               NaN             NaN             NaN
# 19724        NaN               NaN             NaN             NaN
# 19725        NaN               NaN             NaN             NaN
# 41832        NaN               NaN             NaN             NaN
# 61909        NaN               NaN             NaN             NaN
# 98254        NaN               NaN             NaN             NaN
# 98255        NaN               NaN             NaN             NaN
# 142588       NaN               NaN             NaN             NaN
# 190497       NaN               NaN             NaN             NaN
# 190498       NaN               NaN             NaN             NaN
# 190499       NaN               NaN             NaN             NaN
# 190500       NaN               NaN             NaN             NaN
# 190501       NaN               NaN             NaN             NaN
# 190502       NaN               NaN             NaN             NaN
# 190503       NaN               NaN             NaN             NaN
# 190504       NaN               NaN             NaN             NaN
# 190505       NaN               NaN             NaN             NaN
# 190506       NaN               NaN             NaN             NaN
# 190507       NaN               NaN             NaN             NaN
# 190508       NaN               NaN             NaN             NaN
# 190509       NaN               NaN             NaN             NaN
# 190510       NaN               NaN             NaN             NaN
# 190511       NaN               NaN             NaN             NaN
# 190512       NaN               NaN             NaN             NaN
# 190513       NaN               NaN             NaN             NaN
# 190514       NaN               NaN             NaN             NaN
# 190515       NaN               NaN             NaN             NaN
# 190516       NaN               NaN             NaN             NaN
# 190517       NaN               NaN             NaN             NaN
# ...          ...               ...             ...             ...
# 1990160      NaN               NaN             NaN             NaN
# 1990161      NaN               NaN             NaN             NaN
# 1990162      NaN               NaN             NaN             NaN
# 1990163      NaN               NaN             NaN             NaN
# 1990164      NaN               NaN             NaN             NaN
# 1990165      NaN               NaN             NaN             NaN
# 1990166      NaN               NaN             NaN             NaN
# 1990167      NaN               NaN             NaN             NaN
# 1990168      NaN               NaN             NaN             NaN
# 1990169      NaN               NaN             NaN             NaN
# 1990170      NaN               NaN             NaN             NaN
# 1990171      NaN               NaN             NaN             NaN
# 1990172      NaN               NaN             NaN             NaN
# 1990173      NaN               NaN             NaN             NaN
# 1990174      NaN               NaN             NaN             NaN
# 1990175      NaN               NaN             NaN             NaN
# 1990176      NaN               NaN             NaN             NaN
# 1990177      NaN               NaN             NaN             NaN
# 1990178      NaN               NaN             NaN             NaN
# 1990179      NaN               NaN             NaN             NaN
# 1990180      NaN               NaN             NaN             NaN
# 1990181      NaN               NaN             NaN             NaN
# 1990182      NaN               NaN             NaN             NaN
# 1990183      NaN               NaN             NaN             NaN
# 1990184      NaN               NaN             NaN             NaN
# 1990185      NaN               NaN             NaN             NaN
# 1990186      NaN               NaN             NaN             NaN
# 1990187      NaN               NaN             NaN             NaN
# 1990188      NaN               NaN             NaN             NaN
# 2027411      NaN               NaN             NaN             NaN
#
#          Sub_metering_3
# 6839                NaN
# 6840                NaN
# 19724               NaN
# 19725               NaN
# 41832               NaN
# 61909               NaN
# 98254               NaN
# 98255               NaN
# 142588              NaN
# 190497              NaN
# 190498              NaN
# 190499              NaN
# 190500              NaN
# 190501              NaN
# 190502              NaN
# 190503              NaN
# 190504              NaN
# 190505              NaN
# 190506              NaN
# 190507              NaN
# 190508              NaN
# 190509              NaN
# 190510              NaN
# 190511              NaN
# 190512              NaN
# 190513              NaN
# 190514              NaN
# 190515              NaN
# 190516              NaN
# 190517              NaN
# ...                 ...
# 1990160             NaN
# 1990161             NaN
# 1990162             NaN
# 1990163             NaN
# 1990164             NaN
# 1990165             NaN
# 1990166             NaN
# 1990167             NaN
# 1990168             NaN
# 1990169             NaN
# 1990170             NaN
# 1990171             NaN
# 1990172             NaN
# 1990173             NaN
# 1990174             NaN
# 1990175             NaN
# 1990176             NaN
# 1990177             NaN
# 1990178             NaN
# 1990179             NaN
# 1990180             NaN
# 1990181             NaN
# 1990182             NaN
# 1990183             NaN
# 1990184             NaN
# 1990185             NaN
# 1990186             NaN
# 1990187             NaN
# 1990188             NaN
# 2027411             NaN
#
# [25979 rows x 9 columns]

# %% [markdown]
# Clearly, the 25979 rows are completely empty.
# Now we fill these rows using **interpolate function** using linear method

# %%
Data = Data.interpolate(method ='linear')

# %% [markdown]
# Checking again if there left any null values.

# %%
Data.isnull().sum()
# Out:
# Date                     0
# Time                     0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %% [markdown]
# ### Missing Values are handled

# %% [markdown]
# # Maximum and Minimum Datestamp

# %%
Data['Date'].min()
# Out:
# Timestamp('2006-12-16 00:00:00')

# %%
Data['Date'].max()
# Out:
# Timestamp('2010-12-11 00:00:00')

# %% [markdown]
# # Reseting Index
# We reset 'Date' as index

# %%
Data.set_index('Date',inplace=True)
Data.head(4)
# Out:
#                 Time  Global_active_power  Global_reactive_power  Voltage  \
# Date
# 2006-12-16  17:24:00                4.216                  0.418   234.84
# 2006-12-16  17:25:00                5.360                  0.436   233.63
# 2006-12-16  17:26:00                5.374                  0.498   233.29
# 2006-12-16  17:27:00                5.388                  0.502   233.74
#
#             Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# Date
# 2006-12-16              18.4             0.0             1.0            17.0
# 2006-12-16              23.0             0.0             1.0            16.0
# 2006-12-16              23.0             0.0             2.0            17.0
# 2006-12-16              23.0             0.0             1.0            17.0

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(30,10))
plt.scatter(Data.index,Data['Voltage'])
plt.tick_params(labelsize=20)
plt.xlabel('Date',fontsize=30)
plt.show()

# %%
Data[['Voltage']].plot(figsize=[30,10],fontsize=20)
plt.legend(fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.show()
# Out:
# C:\Users\SS\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# There is some trend and seasonality in voltage. But it is not clearly as Data is two large.
#
# So, we group data by dates as we have data on per hour.

# %%
Data = Data.groupby('Date')
Data

# %%
Data = Data.mean()

# %%
Data.head()
# Out:
#             Global_active_power  Global_reactive_power     Voltage  \
# Date
# 2006-12-16             3.053475               0.088187  236.243763
# 2006-12-17             2.354486               0.156949  240.087028
# 2006-12-18             1.530435               0.112356  241.231694
# 2006-12-19             1.157079               0.104821  241.999313
# 2006-12-20             1.545658               0.111804  242.308063
#
#             Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# Date
# 2006-12-16         13.082828        0.000000        1.378788       12.439394
# 2006-12-17          9.999028        1.411806        2.907639        9.264583
# 2006-12-18          6.421667        0.738194        1.820139        9.734722
# 2006-12-19          4.926389        0.582639        5.279167        4.303472
# 2006-12-20          6.467361        0.000000        1.838889        9.765972

# %%
Data.tail()
# Out:
#             Global_active_power  Global_reactive_power     Voltage  \
# Date
# 2010-12-07             0.770538               0.198550  240.218646
# 2010-12-08             0.367846               0.117429  240.794931
# 2010-12-09             1.119508               0.139832  241.619722
# 2010-12-10             1.097008               0.118242  240.260674
# 2010-12-11             1.275571               0.104961  238.837896
#
#             Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# Date
# 2010-12-07          3.397222        1.197222        0.448611        4.475000
# 2010-12-08          1.623750        0.000000        0.356944        2.765278
# 2010-12-09          4.755694        1.253472        1.444444        6.174306
# 2010-12-10          4.681389        0.766667        0.541667        6.813889
# 2010-12-11          5.434861        1.426389        0.339583        7.158333

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1442 entries, 2006-12-16 to 2010-12-11
# Data columns (total 7 columns):
# Global_active_power      1442 non-null float64
# Global_reactive_power    1442 non-null float64
# Voltage                  1442 non-null float64
# Global_intensity         1442 non-null float64
# Sub_metering_1           1442 non-null float64
# Sub_metering_2           1442 non-null float64
# Sub_metering_3           1442 non-null float64
# dtypes: float64(7)
# memory usage: 90.1 KB

# %% [markdown]
# 20 Lakh enteries of original Data changed to 1442 enteries

# %%
Data[['Voltage']].plot(figsize=[30,10],fontsize=20,legend=False)
plt.legend(fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.show()

# %% [markdown]
# ## Since In this project we are going to forecast voltage. So for that and for EDA we separate our data with Train Data and Test Data.
# ### From minimum and maximum date we have data of almost 4 year. So, we use 3 years for train data and 1 year for test data.

# %%
train_data = Data[0:1072]
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1072 entries, 2006-12-16 to 2009-11-21
# Data columns (total 7 columns):
# Global_active_power      1072 non-null float64
# Global_reactive_power    1072 non-null float64
# Voltage                  1072 non-null float64
# Global_intensity         1072 non-null float64
# Sub_metering_1           1072 non-null float64
# Sub_metering_2           1072 non-null float64
# Sub_metering_3           1072 non-null float64
# dtypes: float64(7)
# memory usage: 67.0 KB

# %%
test_data = Data[1072:]
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 370 entries, 2009-11-22 to 2010-12-11
# Data columns (total 7 columns):
# Global_active_power      370 non-null float64
# Global_reactive_power    370 non-null float64
# Voltage                  370 non-null float64
# Global_intensity         370 non-null float64
# Sub_metering_1           370 non-null float64
# Sub_metering_2           370 non-null float64
# Sub_metering_3           370 non-null float64
# dtypes: float64(7)
# memory usage: 23.1 KB

# %%
train_data[['Voltage']].plot(figsize=[30,10],fontsize=20)
plt.legend(fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.show()

# %% [markdown]
# ### Since it has trend and seasonality. We decompose it in different parts.

# %% [markdown]
# ## Importing module for decomposition

# %%
import statsmodels.api as sm

# %%
# check columns 
train_data.columns

# Output: Index(['Milk in pounds per cow'], dtype='object')
timeseries = train_data['Voltage']

# Decomposition of multiplicative time series
decomposition = sm.tsa.seasonal_decompose(timeseries, model='multiplicative')

# Visualisation
fig = decomposition.plot()
fig.set_figwidth(20)
fig.set_figheight(12)
fig.suptitle('Decomposition of multiplicative time series',fontsize=20)
plt.show()

# %% [markdown]
# Seasonaity is not clear from this also.
# So, we try to decomose a small data.

# %%
# check columns 
train_data.columns

# Output: Index(['Milk in pounds per cow'], dtype='object')
timeseries2 = train_data['Voltage'][0:100]

# Decomposition of multiplicative time series
decomposition2 = sm.tsa.seasonal_decompose(timeseries2, model='multiplicative')

# Visualisation
fig2 = decomposition2.plot()
fig2.set_figwidth(12)
fig2.set_figheight(8)
fig2.suptitle('Decomposition of multiplicative time series',fontsize=12)
plt.show()

# %% [markdown]
# **The following are some of our key observations from this analysis:**
#
# 1) Trend: Looks quite similar to a straight line hence we could have easily used linear regression to estimate the trend in this data.
#
# 2) Seasonality: as discussed, seasonal plot displays a fairly consistent month-on-month pattern. The monthly seasonal components are average values for a month after removal of trend. Trend is removed from the time series using the following formula:
#
# 3) Irregular Remainder (random): is the residual left in the series after removal of trend and seasonal components. Remainder is calculated using the following formula:
#
# The expectations from remainder component are that it should look like white noise i.e. displays no pattern at all.

# %%
#Time series plot
plt.figure(figsize=(30,10))
timeseries.rolling(12).mean().plot(label='12 Month Rolling Mean')
timeseries.plot(fontsize=20)
plt.legend(fontsize=30)
# plt.tick_params(labelsize=20)
plt.xlabel('Date',fontsize=30)
plt.show()

# %%
#Time series plot
timeseries2.rolling(12).mean().plot(label='12 Month Rolling Mean')
timeseries2.plot()
plt.legend()
plt.show()
